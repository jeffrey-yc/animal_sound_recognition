# %%
import numpy as np
import pandas as pd
import os

# traiing data related paths
PATH_TRAIN_IN_16KWAVS = './TW_frog_16k_wav/' # frog's 16khz wav forder
PATH_TRAIN_IN_XMLFILES = './TW_frog_16k_xml/' # the path where the XML meta-data files are located

# %%
df = pd.read_csv('species_mapping.csv', encoding='utf-8')
df
# Out:
#    category classId chineseName                           scientificName
# 0      frog  f00001        中國樹蟾                           Hyla chinensis
# 1      frog  f00002        亞洲錦蛙                          Kaloula pulchra
# 2      frog  f00003        古氏赤蛙    Rana kuhlii (Limnonectes fujianensis)
# 3      frog  f00004        台北樹蛙                   Rhacophorus taipeianus
# 4      frog  f00005        台北赤蛙                     Hylarana taipehensis
# 5      frog  f00006     史丹吉氏小雨蛙                    Micryletta steinegeri
# 6      frog  f00007        太田樹蛙                           Buergeria otai
# 7      frog  f00008         小雨蛙                         Microhyla ornata
# 8      frog  f00009       巴氏小雨蛙                        Microhyla butleri
# 9      frog  f00010      拉都希氏赤蛙                       Hylarana latouchii
# 10     frog  f00011        斑腿樹蛙                 Polypedates megacephalus
# 11     frog  f00012      斯文豪氏赤蛙                       Odorrana swinhoana
# 12     frog  f00013        日本樹蛙                       Buergeria japonica
# 13     frog  f00014       梭德氏赤蛙                             Rana sauteri
# 14     frog  f00015        橙腹樹蛙               Rhacophorus aurantiventris
# 15     frog  f00016          海蛙                    Fejervarya cancrivora
# 16     frog  f00017          澤蛙  Fejervarya kawamurai (Rana limnocharis)
# 17     frog  f00018  白頷樹蛙(布氏樹蛙)                      Polypedates braueri
# 18     frog  f00019        盤古蟾蜍                         Bufo bankorensis
# 19     frog  f00020       福建大頭蛙                  Limnonectes fujianensis
# 20     frog  f00021        美洲牛蛙                  Lithobates catesbeianus
# 21     frog  f00022        翡翠樹蛙                   Rhacophorus prasinatus
# 22     frog  f00023         腹斑蛙                       Babina adenopleura
# 23     frog  f00024        艾氏樹蛙                     Kurixalus eiffingeri
# 24     frog  f00025        花狹口蛙                          Kaloula pulchra
# 25     frog  f00026        莫氏樹蛙                   Rhacophorus moltrechti
# 26     frog  f00027         虎皮蛙                 Hoplobatrachus rugulosus
# 27     frog  f00028         褐樹蛙                        Buergeria robusta
# 28     frog  f00029        諸羅樹蛙                      Rhacophorus arvalis
# 29     frog  f00030         豎琴蛙          Babina okinavana (Rana psaltes)
# 30     frog  f00031       貢德氏赤蛙                       Hylarana guentheri
# 31     frog  f00032         金線蛙                   Pelophylax fukienensis
# 32     frog  f00033        長腳赤蛙                           Rana longicrus
# 33     frog  f00034        面天樹蛙                     Kurixalus idiootocus
# 34     frog  f00035        黑眶蟾蜍                Duttaphrynus melanosticus
# 35     frog  f00036     黑蒙西氏小雨蛙                       Microhyla heymonsi

# %%
for path, subdirs, files in os.walk(PATH_TRAIN_IN_16KWAVS):
    i=1
    for name in files:
        if (name.endswith('.wav')):
            print('#{} - Generating XML for {}'.format(i, os.path.join(path, name)))
            tempFileName = name.split('.')[0]
            cName = name.split(' ')[0]
            cId = df[df['chineseName'] == cName]['classId'].item()
            sName = df[df['chineseName'] == cName]['scientificName'].item()
            print('  (cName, cId, sName)=({},{},{})'.format(cName, cId, sName))
            
            tempXmlFile = open(os.path.join(PATH_TRAIN_IN_XMLFILES, tempFileName + '.xml'), 'w', encoding="utf-8")

            tempXmlFile.write('<?xml version="1.0" encoding="UTF-8"?>\n')
            tempXmlFile.write('<Audio>\n')
            tempXmlFile.write('  <MediaId>{}</MediaId>\n'.format(i))
            tempXmlFile.write('  <FileName>{}.wav</FileName>\n'.format(tempFileName))
            tempXmlFile.write('  <ClassId>{}</ClassId>\n'.format(cId))
            tempXmlFile.write('  <Date>2018-04-12</Date>\n')
            tempXmlFile.write('  <Time>15:00</Time>\n')
            tempXmlFile.write('  <Locality>Taiwan</Locality>\n')
            tempXmlFile.write('  <Latitude>0</Latitude>\n')
            tempXmlFile.write('  <Longitude>0</Longitude>\n')
            tempXmlFile.write('  <Elevation>0</Elevation>\n')
            tempXmlFile.write('  <Author>AIA2018</Author>\n')
            tempXmlFile.write('  <AuthorID>AIA2018</AuthorID>\n')
            tempXmlFile.write('  <Content>song</Content>\n')
            tempXmlFile.write('  <Comments />\n')
            tempXmlFile.write('  <Quality>2</Quality>\n')
            tempXmlFile.write('  <Year>AIA2018</Year>\n')
            tempXmlFile.write('  <BackgroundSpecies>XXXXX</BackgroundSpecies>\n')
            tempXmlFile.write('  <Order>XXXXX</Order>\n')
            tempXmlFile.write('  <Family>XXXXX</Family>\n')
            tempXmlFile.write('  <Genus>Rana</Genus>\n')
            tempXmlFile.write('  <Species>{}</Species>\n'.format(sName))
            tempXmlFile.write('  <Sub-species />\n')
            tempXmlFile.write('  <VernacularNames>XXXXX</VernacularNames>\n')
            tempXmlFile.write('</Audio>\n')

            i += 1
            tempXmlFile.close()
# Out:
# #1 - Generating XML for ./TW_frog_16k_wav/小雨蛙 Microhyla ornata_130714.wav
#   (cName, cId, sName)=(小雨蛙,f00008,Microhyla ornata)
# #2 - Generating XML for ./TW_frog_16k_wav/台北赤蛙 Hylarana taipehensis_Hylarana taipehensis.wav
#   (cName, cId, sName)=(台北赤蛙,f00005,Hylarana taipehensis)
# #3 - Generating XML for ./TW_frog_16k_wav/艾氏樹蛙 Kurixalus eiffingeri_13517722641yv9-l.wav
#   (cName, cId, sName)=(艾氏樹蛙,f00024,Kurixalus eiffingeri)
# #4 - Generating XML for ./TW_frog_16k_wav/艾氏樹蛙 Kurixalus eiffingeri_13417408791h7k-l.wav
#   (cName, cId, sName)=(艾氏樹蛙,f00024,Kurixalus eiffingeri)
# #5 - Generating XML for ./TW_frog_16k_wav/豎琴蛙 Babina okinavana (Rana psaltes)_20130818.wav
#   (cName, cId, sName)=(豎琴蛙,f00030,Babina okinavana (Rana psaltes))
# #6 - Generating XML for ./TW_frog_16k_wav/巴氏小雨蛙 Microhyla butleri_巴氏小雨蛙_鳴叫 - YouTube (360p).wav
#   (cName, cId, sName)=(巴氏小雨蛙,f00009,Microhyla butleri)
# #7 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_1322105523-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #8 - Generating XML for ./TW_frog_16k_wav/莫氏樹蛙 Rhacophorus moltrechti_蟲之森 莫氏樹蛙悅耳的鳴叫聲 ... - YouTube (480p).wav
#   (cName, cId, sName)=(莫氏樹蛙,f00026,Rhacophorus moltrechti)
# #9 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_黑眶蟾蜍 叫聲 - YouTube (360p).wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #10 - Generating XML for ./TW_frog_16k_wav/貢德氏赤蛙 Hylarana guentheri_138629447813ah-l.wav
#   (cName, cId, sName)=(貢德氏赤蛙,f00031,Hylarana guentheri)
# #11 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_13496763261j8p-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #12 - Generating XML for ./TW_frog_16k_wav/小雨蛙 Microhyla ornata_1349748532197m-l.wav
#   (cName, cId, sName)=(小雨蛙,f00008,Microhyla ornata)
# #13 - Generating XML for ./TW_frog_16k_wav/艾氏樹蛙 Kurixalus eiffingeri_13497564671bfs-l.wav
#   (cName, cId, sName)=(艾氏樹蛙,f00024,Kurixalus eiffingeri)
# #14 - Generating XML for ./TW_frog_16k_wav/黑蒙西氏小雨蛙 Microhyla heymonsi_黑蒙西氏小雨蛙-完整聲音檔 - YouTube (360p).wav
#   (cName, cId, sName)=(黑蒙西氏小雨蛙,f00036,Microhyla heymonsi)
# #15 - Generating XML for ./TW_frog_16k_wav/斯文豪氏赤蛙 Odorrana swinhoana_13648951891zqa-l.wav
#   (cName, cId, sName)=(斯文豪氏赤蛙,f00012,Odorrana swinhoana)
# #16 - Generating XML for ./TW_frog_16k_wav/拉都希氏赤蛙 Hylarana latouchii_1322147127-l.wav
#   (cName, cId, sName)=(拉都希氏赤蛙,f00010,Hylarana latouchii)
# #17 - Generating XML for ./TW_frog_16k_wav/花狹口蛙 Kaloula pulchra_Kaloula_pulchra.wav
#   (cName, cId, sName)=(花狹口蛙,f00025,Kaloula pulchra)
# #18 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_13388620001ho4-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #19 - Generating XML for ./TW_frog_16k_wav/澤蛙 Fejervarya kawamurai (Rana limnocharis)_1322131159-l.wav
#   (cName, cId, sName)=(澤蛙,f00017,Fejervarya kawamurai (Rana limnocharis))
# #20 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_133886177116mv-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #21 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_13417346121m2z-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #22 - Generating XML for ./TW_frog_16k_wav/莫氏樹蛙 Rhacophorus moltrechti_國家公園行動圖鑑 A0004s001.wav
#   (cName, cId, sName)=(莫氏樹蛙,f00026,Rhacophorus moltrechti)
# #23 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_黑眶蟾蜍叫聲 - YouTube (480p).wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #24 - Generating XML for ./TW_frog_16k_wav/澤蛙 Fejervarya kawamurai (Rana limnocharis)_澤蛙叫聲 - YouTube (480p).wav
#   (cName, cId, sName)=(澤蛙,f00017,Fejervarya kawamurai (Rana limnocharis))
# #25 - Generating XML for ./TW_frog_16k_wav/腹斑蛙 Babina adenopleura_13704895581qbf-l.wav
#   (cName, cId, sName)=(腹斑蛙,f00023,Babina adenopleura)
# #26 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_1322146587-l.wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #27 - Generating XML for ./TW_frog_16k_wav/長腳赤蛙 Rana longicrus_Rana_longicrus.wav
#   (cName, cId, sName)=(長腳赤蛙,f00033,Rana longicrus)
# #28 - Generating XML for ./TW_frog_16k_wav/海蛙 Fejervarya cancrivora_13729217941myy-l.wav
#   (cName, cId, sName)=(海蛙,f00016,Fejervarya cancrivora)
# #29 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_1322142194-l.wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #30 - Generating XML for ./TW_frog_16k_wav/豎琴蛙 Babina okinavana (Rana psaltes)_Rana_psaltes.wav
#   (cName, cId, sName)=(豎琴蛙,f00030,Babina okinavana (Rana psaltes))
# #31 - Generating XML for ./TW_frog_16k_wav/斯文豪氏赤蛙 Odorrana swinhoana_13648934941gof-l.wav
#   (cName, cId, sName)=(斯文豪氏赤蛙,f00012,Odorrana swinhoana)
# #32 - Generating XML for ./TW_frog_16k_wav/翡翠樹蛙 Rhacophorus prasinatus_13517716821zxy-l.wav
#   (cName, cId, sName)=(翡翠樹蛙,f00022,Rhacophorus prasinatus)
# #33 - Generating XML for ./TW_frog_16k_wav/斯文豪氏赤蛙 Odorrana swinhoana_國家公園行動圖鑑 A0016s001.wav
#   (cName, cId, sName)=(斯文豪氏赤蛙,f00012,Odorrana swinhoana)
# #34 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_13497513571ixs-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #35 - Generating XML for ./TW_frog_16k_wav/盤古蟾蜍 Bufo bankorensis_134173559418yi-l.wav
#   (cName, cId, sName)=(盤古蟾蜍,f00019,Bufo bankorensis)
# #36 - Generating XML for ./TW_frog_16k_wav/拉都希氏赤蛙 Hylarana latouchii_138683226312jj-l.wav
#   (cName, cId, sName)=(拉都希氏赤蛙,f00010,Hylarana latouchii)
# #37 - Generating XML for ./TW_frog_16k_wav/亞洲錦蛙 Kaloula pulchra_13783673301zid-l.wav
#   (cName, cId, sName)=(亞洲錦蛙,f00002,Kaloula pulchra)
# #38 - Generating XML for ./TW_frog_16k_wav/太田樹蛙 Buergeria otai_151210611314gq-l.wav
#   (cName, cId, sName)=(太田樹蛙,f00007,Buergeria otai)
# #39 - Generating XML for ./TW_frog_16k_wav/豎琴蛙 Babina okinavana (Rana psaltes)_20130615.wav
#   (cName, cId, sName)=(豎琴蛙,f00030,Babina okinavana (Rana psaltes))
# #40 - Generating XML for ./TW_frog_16k_wav/小雨蛙 Microhyla ornata_13497537291xii-l.wav
#   (cName, cId, sName)=(小雨蛙,f00008,Microhyla ornata)
# #41 - Generating XML for ./TW_frog_16k_wav/面天樹蛙 Kurixalus idiootocus_Chirixalus_idiootocus.wav
#   (cName, cId, sName)=(面天樹蛙,f00034,Kurixalus idiootocus)
# #42 - Generating XML for ./TW_frog_16k_wav/澤蛙 Fejervarya kawamurai (Rana limnocharis)_13720623331y5s-l.wav
#   (cName, cId, sName)=(澤蛙,f00017,Fejervarya kawamurai (Rana limnocharis))
# #43 - Generating XML for ./TW_frog_16k_wav/橙腹樹蛙 Rhacophorus aurantiventris_137716195011cn-l.wav
#   (cName, cId, sName)=(橙腹樹蛙,f00015,Rhacophorus aurantiventris)
# #44 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_1322141363-l.wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #45 - Generating XML for ./TW_frog_16k_wav/長腳赤蛙 Rana longicrus_1384861843123a-l.wav
#   (cName, cId, sName)=(長腳赤蛙,f00033,Rana longicrus)
# #46 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_13497514601bcg-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #47 - Generating XML for ./TW_frog_16k_wav/豎琴蛙 Babina okinavana (Rana psaltes)_A0033s001.wav
#   (cName, cId, sName)=(豎琴蛙,f00030,Babina okinavana (Rana psaltes))
# #48 - Generating XML for ./TW_frog_16k_wav/黑蒙西氏小雨蛙 Microhyla heymonsi_黑蒙西氏小雨蛙 - YouTube (360p).wav
#   (cName, cId, sName)=(黑蒙西氏小雨蛙,f00036,Microhyla heymonsi)
# #49 - Generating XML for ./TW_frog_16k_wav/面天樹蛙 Kurixalus idiootocus_國家公園行動圖鑑 A0011s001.wav
#   (cName, cId, sName)=(面天樹蛙,f00034,Kurixalus idiootocus)
# #50 - Generating XML for ./TW_frog_16k_wav/褐樹蛙 Buergeria robusta_國家公園行動圖鑑  A0005s001.wav
#   (cName, cId, sName)=(褐樹蛙,f00028,Buergeria robusta)
# #51 - Generating XML for ./TW_frog_16k_wav/福建大頭蛙 Limnonectes fujianensis_13648946451n9y-l.wav
#   (cName, cId, sName)=(福建大頭蛙,f00020,Limnonectes fujianensis)
# #52 - Generating XML for ./TW_frog_16k_wav/長腳赤蛙 Rana longicrus_13848617711vwj-l.wav
#   (cName, cId, sName)=(長腳赤蛙,f00033,Rana longicrus)
# #53 - Generating XML for ./TW_frog_16k_wav/史丹吉氏小雨蛙 Micryletta steinegeri_20130824-1.wav
#   (cName, cId, sName)=(史丹吉氏小雨蛙,f00006,Micryletta steinegeri)
# #54 - Generating XML for ./TW_frog_16k_wav/中國樹蟾 Hyla chinensis_中國樹蟾鳴叫2 - YouTube (480p).wav
#   (cName, cId, sName)=(中國樹蟾,f00001,Hyla chinensis)
# #55 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_134975553118mj-l.wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #56 - Generating XML for ./TW_frog_16k_wav/史丹吉氏小雨蛙 Micryletta steinegeri_13497535941g4n-l.wav
#   (cName, cId, sName)=(史丹吉氏小雨蛙,f00006,Micryletta steinegeri)
# #57 - Generating XML for ./TW_frog_16k_wav/澤蛙 Fejervarya kawamurai (Rana limnocharis)_1322107286-l.wav
#   (cName, cId, sName)=(澤蛙,f00017,Fejervarya kawamurai (Rana limnocharis))
# #58 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_黑眶蟾蜍影片(雄鳴叫)20130419(好涼亭) - YouTube (480p).wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #59 - Generating XML for ./TW_frog_16k_wav/貢德氏赤蛙 Hylarana guentheri_A0019s001.wav
#   (cName, cId, sName)=(貢德氏赤蛙,f00031,Hylarana guentheri)
# #60 - Generating XML for ./TW_frog_16k_wav/福建大頭蛙 Limnonectes fujianensis_137716121417pe-l.wav
#   (cName, cId, sName)=(福建大頭蛙,f00020,Limnonectes fujianensis)
# #61 - Generating XML for ./TW_frog_16k_wav/台北赤蛙 Hylarana taipehensis_國家公園行動圖鑑 A0017s001.wav
#   (cName, cId, sName)=(台北赤蛙,f00005,Hylarana taipehensis)
# #62 - Generating XML for ./TW_frog_16k_wav/史丹吉氏小雨蛙 Micryletta steinegeri_140810.wav
#   (cName, cId, sName)=(史丹吉氏小雨蛙,f00006,Micryletta steinegeri)
# #63 - Generating XML for ./TW_frog_16k_wav/艾氏樹蛙 Kurixalus eiffingeri_國家公園行動圖鑑 A0010s001.wav
#   (cName, cId, sName)=(艾氏樹蛙,f00024,Kurixalus eiffingeri)
# #64 - Generating XML for ./TW_frog_16k_wav/巴氏小雨蛙 Microhyla butleri_1322138885-l.wav
#   (cName, cId, sName)=(巴氏小雨蛙,f00009,Microhyla butleri)
# #65 - Generating XML for ./TW_frog_16k_wav/中國樹蟾 Hyla chinensis_134975265413jl-l.wav
#   (cName, cId, sName)=(中國樹蟾,f00001,Hyla chinensis)
# #66 - Generating XML for ./TW_frog_16k_wav/金線蛙 Pelophylax fukienensis_1386832275118l-l.wav
#   (cName, cId, sName)=(金線蛙,f00032,Pelophylax fukienensis)
# #67 - Generating XML for ./TW_frog_16k_wav/斯文豪氏赤蛙 Odorrana swinhoana_136489541019tx-l.wav
#   (cName, cId, sName)=(斯文豪氏赤蛙,f00012,Odorrana swinhoana)
# #68 - Generating XML for ./TW_frog_16k_wav/海蛙 Fejervarya cancrivora_Rana_cancrivora.wav
#   (cName, cId, sName)=(海蛙,f00016,Fejervarya cancrivora)
# #69 - Generating XML for ./TW_frog_16k_wav/莫氏樹蛙 Rhacophorus moltrechti_13388601071wnh-l.wav
#   (cName, cId, sName)=(莫氏樹蛙,f00026,Rhacophorus moltrechti)
# #70 - Generating XML for ./TW_frog_16k_wav/艾氏樹蛙 Kurixalus eiffingeri_艾氏樹蛙 - YouTube (480p).wav
#   (cName, cId, sName)=(艾氏樹蛙,f00024,Kurixalus eiffingeri)
# #71 - Generating XML for ./TW_frog_16k_wav/腹斑蛙 Babina adenopleura_1322106399-l.wav
#   (cName, cId, sName)=(腹斑蛙,f00023,Babina adenopleura)
# #72 - Generating XML for ./TW_frog_16k_wav/小雨蛙 Microhyla ornata_1322146415-l.wav
#   (cName, cId, sName)=(小雨蛙,f00008,Microhyla ornata)
# #73 - Generating XML for ./TW_frog_16k_wav/虎皮蛙 Hoplobatrachus rugulosus_13497482751ksw-l.wav
#   (cName, cId, sName)=(虎皮蛙,f00027,Hoplobatrachus rugulosus)
# #74 - Generating XML for ./TW_frog_16k_wav/海蛙 Fejervarya cancrivora_137292188517fu-l.wav
#   (cName, cId, sName)=(海蛙,f00016,Fejervarya cancrivora)
# #75 - Generating XML for ./TW_frog_16k_wav/小雨蛙 Microhyla ornata_2-1-1_01.wav
#   (cName, cId, sName)=(小雨蛙,f00008,Microhyla ornata)
# #76 - Generating XML for ./TW_frog_16k_wav/面天樹蛙 Kurixalus idiootocus_面天樹蛙鳴叫求偶 - YouTube (480p).wav
#   (cName, cId, sName)=(面天樹蛙,f00034,Kurixalus idiootocus)
# #77 - Generating XML for ./TW_frog_16k_wav/艾氏樹蛙 Kurixalus eiffingeri_134174017617xc-l.wav
#   (cName, cId, sName)=(艾氏樹蛙,f00024,Kurixalus eiffingeri)
# #78 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_13497522131mln-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #79 - Generating XML for ./TW_frog_16k_wav/史丹吉氏小雨蛙 Micryletta steinegeri_134967581911rr-l.wav
#   (cName, cId, sName)=(史丹吉氏小雨蛙,f00006,Micryletta steinegeri)
# #80 - Generating XML for ./TW_frog_16k_wav/巴氏小雨蛙 Microhyla butleri_13497493181148-l.wav
#   (cName, cId, sName)=(巴氏小雨蛙,f00009,Microhyla butleri)
# #81 - Generating XML for ./TW_frog_16k_wav/巴氏小雨蛙 Microhyla butleri_1322138685-l.wav
#   (cName, cId, sName)=(巴氏小雨蛙,f00009,Microhyla butleri)
# #82 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_13388618931jfx-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #83 - Generating XML for ./TW_frog_16k_wav/亞洲錦蛙 Kaloula pulchra_138683223018rt-l.wav
#   (cName, cId, sName)=(亞洲錦蛙,f00002,Kaloula pulchra)
# #84 - Generating XML for ./TW_frog_16k_wav/翡翠樹蛙 Rhacophorus prasinatus_135177188415nb-l.wav
#   (cName, cId, sName)=(翡翠樹蛙,f00022,Rhacophorus prasinatus)
# #85 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_Duttaphrynus_melanosticus.wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #86 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_13496761191sfc-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #87 - Generating XML for ./TW_frog_16k_wav/斑腿樹蛙 Polypedates megacephalus_13521851171vai-l.wav
#   (cName, cId, sName)=(斑腿樹蛙,f00011,Polypedates megacephalus)
# #88 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_134975171113r1-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #89 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_13417247931pwy-l.wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #90 - Generating XML for ./TW_frog_16k_wav/亞洲錦蛙 Kaloula pulchra_1383189065183d-l.wav
#   (cName, cId, sName)=(亞洲錦蛙,f00002,Kaloula pulchra)
# #91 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_20130824-2.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #92 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_13497512751t7b-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #93 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_13388615901nec-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #94 - Generating XML for ./TW_frog_16k_wav/中國樹蟾 Hyla chinensis_Hyla_chinensis.wav
#   (cName, cId, sName)=(中國樹蟾,f00001,Hyla chinensis)
# #95 - Generating XML for ./TW_frog_16k_wav/台北樹蛙 Rhacophorus taipeianus_13417410181pdd-l.wav
#   (cName, cId, sName)=(台北樹蛙,f00004,Rhacophorus taipeianus)
# #96 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_Buergeria_japonicus.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #97 - Generating XML for ./TW_frog_16k_wav/貢德氏赤蛙 Hylarana guentheri_2013070702.wav
#   (cName, cId, sName)=(貢德氏赤蛙,f00031,Hylarana guentheri)
# #98 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_國家公園行動圖鑑 A0009s001.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #99 - Generating XML for ./TW_frog_16k_wav/莫氏樹蛙 Rhacophorus moltrechti_莫氏樹蛙鳴叫聲 Rhacophorus moltrechti - YouTube (480p).wav
#   (cName, cId, sName)=(莫氏樹蛙,f00026,Rhacophorus moltrechti)
# #100 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_13497519941kzi-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #101 - Generating XML for ./TW_frog_16k_wav/莫氏樹蛙 Rhacophorus moltrechti_140323.wav
#   (cName, cId, sName)=(莫氏樹蛙,f00026,Rhacophorus moltrechti)
# #102 - Generating XML for ./TW_frog_16k_wav/豎琴蛙 Babina okinavana (Rana psaltes)_13729216261ex3-l.wav
#   (cName, cId, sName)=(豎琴蛙,f00030,Babina okinavana (Rana psaltes))
# #103 - Generating XML for ./TW_frog_16k_wav/虎皮蛙 Hoplobatrachus rugulosus_13771631401jik-l.wav
#   (cName, cId, sName)=(虎皮蛙,f00027,Hoplobatrachus rugulosus)
# #104 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_13496760471v9s-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #105 - Generating XML for ./TW_frog_16k_wav/中國樹蟾 Hyla chinensis_13496768331j46-l.wav
#   (cName, cId, sName)=(中國樹蟾,f00001,Hyla chinensis)
# #106 - Generating XML for ./TW_frog_16k_wav/莫氏樹蛙 Rhacophorus moltrechti_13388648591kzi-l.wav
#   (cName, cId, sName)=(莫氏樹蛙,f00026,Rhacophorus moltrechti)
# #107 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_150809.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #108 - Generating XML for ./TW_frog_16k_wav/小雨蛙 Microhyla ornata_13781806751tax-l.wav
#   (cName, cId, sName)=(小雨蛙,f00008,Microhyla ornata)
# #109 - Generating XML for ./TW_frog_16k_wav/豎琴蛙 Babina okinavana (Rana psaltes)_13781769071eid-l.wav
#   (cName, cId, sName)=(豎琴蛙,f00030,Babina okinavana (Rana psaltes))
# #110 - Generating XML for ./TW_frog_16k_wav/豎琴蛙 Babina okinavana (Rana psaltes)_13771628691vcx-l.wav
#   (cName, cId, sName)=(豎琴蛙,f00030,Babina okinavana (Rana psaltes))
# #111 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_13497518051uoj-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #112 - Generating XML for ./TW_frog_16k_wav/貢德氏赤蛙 Hylarana guentheri_1322101101-l.wav
#   (cName, cId, sName)=(貢德氏赤蛙,f00031,Hylarana guentheri)
# #113 - Generating XML for ./TW_frog_16k_wav/美洲牛蛙 Lithobates catesbeianus_13848617521w1h-l.wav
#   (cName, cId, sName)=(美洲牛蛙,f00021,Lithobates catesbeianus)
# #114 - Generating XML for ./TW_frog_16k_wav/澤蛙 Fejervarya kawamurai (Rana limnocharis)_13497481211ewa-l.wav
#   (cName, cId, sName)=(澤蛙,f00017,Fejervarya kawamurai (Rana limnocharis))
# #115 - Generating XML for ./TW_frog_16k_wav/長腳赤蛙 Rana longicrus_A0022s001.wav
#   (cName, cId, sName)=(長腳赤蛙,f00033,Rana longicrus)
# #116 - Generating XML for ./TW_frog_16k_wav/腹斑蛙 Babina adenopleura_國家公園行動圖鑑 A0015s001.wav
#   (cName, cId, sName)=(腹斑蛙,f00023,Babina adenopleura)
# #117 - Generating XML for ./TW_frog_16k_wav/台北赤蛙 Hylarana taipehensis_13729081351cxc-l.wav
#   (cName, cId, sName)=(台北赤蛙,f00005,Hylarana taipehensis)
# #118 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_1322139681-l.wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #119 - Generating XML for ./TW_frog_16k_wav/黑蒙西氏小雨蛙 Microhyla heymonsi_1322138053-l.wav
#   (cName, cId, sName)=(黑蒙西氏小雨蛙,f00036,Microhyla heymonsi)
# #120 - Generating XML for ./TW_frog_16k_wav/橙腹樹蛙 Rhacophorus aurantiventris_13729208141liq-l.wav
#   (cName, cId, sName)=(橙腹樹蛙,f00015,Rhacophorus aurantiventris)
# #121 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_黑眶蟾蜍鳴叫 - YouTube (360p).wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #122 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_150315-007.wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #123 - Generating XML for ./TW_frog_16k_wav/褐樹蛙 Buergeria robusta_13496778351kks-l.wav
#   (cName, cId, sName)=(褐樹蛙,f00028,Buergeria robusta)
# #124 - Generating XML for ./TW_frog_16k_wav/小雨蛙 Microhyla ornata_Microhyla_ornata.wav
#   (cName, cId, sName)=(小雨蛙,f00008,Microhyla ornata)
# #125 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_白頷樹蛙 - YouTube (480p).wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #126 - Generating XML for ./TW_frog_16k_wav/面天樹蛙 Kurixalus idiootocus_面天樹蛙鳴唱.wmv - YouTube (480p).wav
#   (cName, cId, sName)=(面天樹蛙,f00034,Kurixalus idiootocus)
# #127 - Generating XML for ./TW_frog_16k_wav/拉都希氏赤蛙 Hylarana latouchii_A0020s001.wav
#   (cName, cId, sName)=(拉都希氏赤蛙,f00010,Hylarana latouchii)
# #128 - Generating XML for ./TW_frog_16k_wav/金線蛙 Pelophylax fukienensis_13781791921iz8-l.wav
#   (cName, cId, sName)=(金線蛙,f00032,Pelophylax fukienensis)
# #129 - Generating XML for ./TW_frog_16k_wav/面天樹蛙 Kurixalus idiootocus_1322140336-l.wav
#   (cName, cId, sName)=(面天樹蛙,f00034,Kurixalus idiootocus)
# #130 - Generating XML for ./TW_frog_16k_wav/翡翠樹蛙 Rhacophorus prasinatus_13517717511n6c-l.wav
#   (cName, cId, sName)=(翡翠樹蛙,f00022,Rhacophorus prasinatus)
# #131 - Generating XML for ./TW_frog_16k_wav/貢德氏赤蛙 Hylarana guentheri_1322118285-l.wav
#   (cName, cId, sName)=(貢德氏赤蛙,f00031,Hylarana guentheri)
# #132 - Generating XML for ./TW_frog_16k_wav/黑蒙西氏小雨蛙 Microhyla heymonsi_黑蒙西氏小雨蛙-連續長音 - YouTube (480p).wav
#   (cName, cId, sName)=(黑蒙西氏小雨蛙,f00036,Microhyla heymonsi)
# #133 - Generating XML for ./TW_frog_16k_wav/史丹吉氏小雨蛙 Micryletta steinegeri_13496759171uq6-l.wav
#   (cName, cId, sName)=(史丹吉氏小雨蛙,f00006,Micryletta steinegeri)
# #134 - Generating XML for ./TW_frog_16k_wav/翡翠樹蛙 Rhacophorus prasinatus_13517715981kbr-l.wav
#   (cName, cId, sName)=(翡翠樹蛙,f00022,Rhacophorus prasinatus)
# #135 - Generating XML for ./TW_frog_16k_wav/斯文豪氏赤蛙 Odorrana swinhoana_13417404901pfp-l.wav
#   (cName, cId, sName)=(斯文豪氏赤蛙,f00012,Odorrana swinhoana)
# #136 - Generating XML for ./TW_frog_16k_wav/古氏赤蛙 Rana kuhlii (Limnonectes fujianensis？？？)_國家公園行動圖鑑 A0012s001.wav
#   (cName, cId, sName)=(古氏赤蛙,f00003,Rana kuhlii (Limnonectes fujianensis))
# #137 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_134975159713cb-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #138 - Generating XML for ./TW_frog_16k_wav/澤蛙 Fejervarya kawamurai (Rana limnocharis)_13226757252qpg-l.wav
#   (cName, cId, sName)=(澤蛙,f00017,Fejervarya kawamurai (Rana limnocharis))
# #139 - Generating XML for ./TW_frog_16k_wav/莫氏樹蛙 Rhacophorus moltrechti_13388604531r2e-l.wav
#   (cName, cId, sName)=(莫氏樹蛙,f00026,Rhacophorus moltrechti)
# #140 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_1322102731-l.wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #141 - Generating XML for ./TW_frog_16k_wav/褐樹蛙 Buergeria robusta_13417347161r5t-l.wav
#   (cName, cId, sName)=(褐樹蛙,f00028,Buergeria robusta)
# #142 - Generating XML for ./TW_frog_16k_wav/黑蒙西氏小雨蛙 Microhyla heymonsi_黑蒙西氏小雨蛙和小雨蛙鳴叫 - YouTube (360p).wav
#   (cName, cId, sName)=(黑蒙西氏小雨蛙,f00036,Microhyla heymonsi)
# #143 - Generating XML for ./TW_frog_16k_wav/美洲牛蛙 Lithobates catesbeianus_138486168417yf-l.wav
#   (cName, cId, sName)=(美洲牛蛙,f00021,Lithobates catesbeianus)
# #144 - Generating XML for ./TW_frog_16k_wav/橙腹樹蛙 Rhacophorus aurantiventris_13771622201361-l.wav
#   (cName, cId, sName)=(橙腹樹蛙,f00015,Rhacophorus aurantiventris)
# #145 - Generating XML for ./TW_frog_16k_wav/斑腿樹蛙 Polypedates megacephalus_13648937491uiv-l.wav
#   (cName, cId, sName)=(斑腿樹蛙,f00011,Polypedates megacephalus)
# #146 - Generating XML for ./TW_frog_16k_wav/褐樹蛙 Buergeria robusta_13771614941crg-l.wav
#   (cName, cId, sName)=(褐樹蛙,f00028,Buergeria robusta)
# #147 - Generating XML for ./TW_frog_16k_wav/腹斑蛙 Babina adenopleura_134174071915vq-l.wav
#   (cName, cId, sName)=(腹斑蛙,f00023,Babina adenopleura)
# #148 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_13417330361seq-l.wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #149 - Generating XML for ./TW_frog_16k_wav/台北赤蛙 Hylarana taipehensis_13729080481zfp-l.wav
#   (cName, cId, sName)=(台北赤蛙,f00005,Hylarana taipehensis)
# #150 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_TBG 兩棲 黑框蟾蜍 求偶的叫聲 20110314 08_44 - YouTube (480p).wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #151 - Generating XML for ./TW_frog_16k_wav/虎皮蛙 Hoplobatrachus rugulosus_虎皮蛙（Chinese Edible Frog Croaking） - YouTube (480p).wav
#   (cName, cId, sName)=(虎皮蛙,f00027,Hoplobatrachus rugulosus)
# #152 - Generating XML for ./TW_frog_16k_wav/金線蛙 Pelophylax fukienensis_13848617131nzx-l.wav
#   (cName, cId, sName)=(金線蛙,f00032,Pelophylax fukienensis)
# #153 - Generating XML for ./TW_frog_16k_wav/台北赤蛙 Hylarana taipehensis_137290792413x4-l.wav
#   (cName, cId, sName)=(台北赤蛙,f00005,Hylarana taipehensis)
# #154 - Generating XML for ./TW_frog_16k_wav/斯文豪氏赤蛙 Odorrana swinhoana_134168189719tx-l.wav
#   (cName, cId, sName)=(斯文豪氏赤蛙,f00012,Odorrana swinhoana)
# #155 - Generating XML for ./TW_frog_16k_wav/腹斑蛙 Babina adenopleura_Rana_adenopleura.wav
#   (cName, cId, sName)=(腹斑蛙,f00023,Babina adenopleura)
# #156 - Generating XML for ./TW_frog_16k_wav/盤古蟾蜍 Bufo bankorensis_國家公園行動圖鑑  A0002s001.wav
#   (cName, cId, sName)=(盤古蟾蜍,f00019,Bufo bankorensis)
# #157 - Generating XML for ./TW_frog_16k_wav/盤古蟾蜍 Bufo bankorensis_134173559418yi-l (1).wav
#   (cName, cId, sName)=(盤古蟾蜍,f00019,Bufo bankorensis)
# #158 - Generating XML for ./TW_frog_16k_wav/梭德氏赤蛙 Rana sauteri_13868323511pr7-l.wav
#   (cName, cId, sName)=(梭德氏赤蛙,f00014,Rana sauteri)
# #159 - Generating XML for ./TW_frog_16k_wav/貢德氏赤蛙 Hylarana guentheri_1322118515-l.wav
#   (cName, cId, sName)=(貢德氏赤蛙,f00031,Hylarana guentheri)
# #160 - Generating XML for ./TW_frog_16k_wav/澤蛙 Fejervarya kawamurai (Rana limnocharis)_1322144062-l.wav
#   (cName, cId, sName)=(澤蛙,f00017,Fejervarya kawamurai (Rana limnocharis))
# #161 - Generating XML for ./TW_frog_16k_wav/豎琴蛙 Babina okinavana (Rana psaltes)_13699022611luf-l.wav
#   (cName, cId, sName)=(豎琴蛙,f00030,Babina okinavana (Rana psaltes))
# #162 - Generating XML for ./TW_frog_16k_wav/中國樹蟾 Hyla chinensis_13496767241evk-l.wav
#   (cName, cId, sName)=(中國樹蟾,f00001,Hyla chinensis)
# #163 - Generating XML for ./TW_frog_16k_wav/台北樹蛙 Rhacophorus taipeianus_20140111.wav
#   (cName, cId, sName)=(台北樹蛙,f00004,Rhacophorus taipeianus)
# #164 - Generating XML for ./TW_frog_16k_wav/面天樹蛙 Kurixalus idiootocus_1322108774-l.wav
#   (cName, cId, sName)=(面天樹蛙,f00034,Kurixalus idiootocus)
# #165 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_13496762541kcv-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #166 - Generating XML for ./TW_frog_16k_wav/盤古蟾蜍 Bufo bankorensis_盤古蟾蜍釋放叫聲 (Release cry) - YouTube (480p).wav
#   (cName, cId, sName)=(盤古蟾蜍,f00019,Bufo bankorensis)
# #167 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_13497521571vly-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #168 - Generating XML for ./TW_frog_16k_wav/豎琴蛙 Babina okinavana (Rana psaltes)_13729215211j2q-l.wav
#   (cName, cId, sName)=(豎琴蛙,f00030,Babina okinavana (Rana psaltes))
# #169 - Generating XML for ./TW_frog_16k_wav/艾氏樹蛙 Kurixalus eiffingeri_134174034914tw-l.wav
#   (cName, cId, sName)=(艾氏樹蛙,f00024,Kurixalus eiffingeri)
# #170 - Generating XML for ./TW_frog_16k_wav/豎琴蛙 Babina okinavana (Rana psaltes)_150411-002.wav
#   (cName, cId, sName)=(豎琴蛙,f00030,Babina okinavana (Rana psaltes))
# #171 - Generating XML for ./TW_frog_16k_wav/巴氏小雨蛙 Microhyla butleri_1322138439-l.wav
#   (cName, cId, sName)=(巴氏小雨蛙,f00009,Microhyla butleri)
# #172 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_134975532219ux-l.wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #173 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_13497522921ryc-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #174 - Generating XML for ./TW_frog_16k_wav/台北樹蛙 Rhacophorus taipeianus_Rhacophorus_taipeianus.wav
#   (cName, cId, sName)=(台北樹蛙,f00004,Rhacophorus taipeianus)
# #175 - Generating XML for ./TW_frog_16k_wav/黑蒙西氏小雨蛙 Microhyla heymonsi_1322131567-l.wav
#   (cName, cId, sName)=(黑蒙西氏小雨蛙,f00036,Microhyla heymonsi)
# #176 - Generating XML for ./TW_frog_16k_wav/褐樹蛙 Buergeria robusta_150315-000.wav
#   (cName, cId, sName)=(褐樹蛙,f00028,Buergeria robusta)
# #177 - Generating XML for ./TW_frog_16k_wav/盤古蟾蜍 Bufo bankorensis_13388695661rnh-l.wav
#   (cName, cId, sName)=(盤古蟾蜍,f00019,Bufo bankorensis)
# #178 - Generating XML for ./TW_frog_16k_wav/莫氏樹蛙 Rhacophorus moltrechti_Rhacophorus_moltrechti.wav
#   (cName, cId, sName)=(莫氏樹蛙,f00026,Rhacophorus moltrechti)
# #179 - Generating XML for ./TW_frog_16k_wav/史丹吉氏小雨蛙 Micryletta steinegeri_13497533071fvc-l.wav
#   (cName, cId, sName)=(史丹吉氏小雨蛙,f00006,Micryletta steinegeri)
# #180 - Generating XML for ./TW_frog_16k_wav/斯文豪氏赤蛙 Odorrana swinhoana_150117-001.wav
#   (cName, cId, sName)=(斯文豪氏赤蛙,f00012,Odorrana swinhoana)
# #181 - Generating XML for ./TW_frog_16k_wav/長腳赤蛙 Rana longicrus_13848618551sv3-l.wav
#   (cName, cId, sName)=(長腳赤蛙,f00033,Rana longicrus)
# #182 - Generating XML for ./TW_frog_16k_wav/美洲牛蛙 Lithobates catesbeianus_13781772641vsr-l.wav
#   (cName, cId, sName)=(美洲牛蛙,f00021,Lithobates catesbeianus)
# #183 - Generating XML for ./TW_frog_16k_wav/梭德氏赤蛙 Rana sauteri_13868323311ddq-l.wav
#   (cName, cId, sName)=(梭德氏赤蛙,f00014,Rana sauteri)
# #184 - Generating XML for ./TW_frog_16k_wav/梭德氏赤蛙 Rana sauteri_13844106671r9s-l.wav
#   (cName, cId, sName)=(梭德氏赤蛙,f00014,Rana sauteri)
# #185 - Generating XML for ./TW_frog_16k_wav/斑腿樹蛙 Polypedates megacephalus_136489363716ti-l.wav
#   (cName, cId, sName)=(斑腿樹蛙,f00011,Polypedates megacephalus)
# #186 - Generating XML for ./TW_frog_16k_wav/巴氏小雨蛙 Microhyla butleri_13497495291erb-l.wav
#   (cName, cId, sName)=(巴氏小雨蛙,f00009,Microhyla butleri)
# #187 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_1349676180146s-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #188 - Generating XML for ./TW_frog_16k_wav/虎皮蛙 Hoplobatrachus rugulosus_13771633711yf5-l.wav
#   (cName, cId, sName)=(虎皮蛙,f00027,Hoplobatrachus rugulosus)
# #189 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_國家公園行動圖鑑  A0001s001.wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #190 - Generating XML for ./TW_frog_16k_wav/澤蛙 Fejervarya kawamurai (Rana limnocharis)_我的富陽朋友  澤蛙 - YouTube (480p).wav
#   (cName, cId, sName)=(澤蛙,f00017,Fejervarya kawamurai (Rana limnocharis))
# #191 - Generating XML for ./TW_frog_16k_wav/斯文豪氏赤蛙 Odorrana swinhoana_137818016715x3-l.wav
#   (cName, cId, sName)=(斯文豪氏赤蛙,f00012,Odorrana swinhoana)
# #192 - Generating XML for ./TW_frog_16k_wav/莫氏樹蛙 Rhacophorus moltrechti_13388650121cfy-l.wav
#   (cName, cId, sName)=(莫氏樹蛙,f00026,Rhacophorus moltrechti)
# #193 - Generating XML for ./TW_frog_16k_wav/斯文豪氏赤蛙 Odorrana swinhoana_13648950981lll-l.wav
#   (cName, cId, sName)=(斯文豪氏赤蛙,f00012,Odorrana swinhoana)
# #194 - Generating XML for ./TW_frog_16k_wav/拉都希氏赤蛙 Hylarana latouchii_150315-004.wav
#   (cName, cId, sName)=(拉都希氏赤蛙,f00010,Hylarana latouchii)
# #195 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_國家公園行動圖鑑 A0006s001.wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #196 - Generating XML for ./TW_frog_16k_wav/小雨蛙 Microhyla ornata_13497486031488-l.wav
#   (cName, cId, sName)=(小雨蛙,f00008,Microhyla ornata)
# #197 - Generating XML for ./TW_frog_16k_wav/史丹吉氏小雨蛙 Micryletta steinegeri_13497534801unt-l.wav
#   (cName, cId, sName)=(史丹吉氏小雨蛙,f00006,Micryletta steinegeri)
# #198 - Generating XML for ./TW_frog_16k_wav/斑腿樹蛙 Polypedates megacephalus_13521849841g87-l.wav
#   (cName, cId, sName)=(斑腿樹蛙,f00011,Polypedates megacephalus)
# #199 - Generating XML for ./TW_frog_16k_wav/中國樹蟾 Hyla chinensis_五一五二..半夜蛙鳴 中國樹蟾 吵翻天 - YouTube (480p).wav
#   (cName, cId, sName)=(中國樹蟾,f00001,Hyla chinensis)
# #200 - Generating XML for ./TW_frog_16k_wav/台北樹蛙 Rhacophorus taipeianus_13648943261iwz-l.wav
#   (cName, cId, sName)=(台北樹蛙,f00004,Rhacophorus taipeianus)
# #201 - Generating XML for ./TW_frog_16k_wav/台北樹蛙 Rhacophorus taipeianus_國家公園行動圖鑑 A0007s001.wav
#   (cName, cId, sName)=(台北樹蛙,f00004,Rhacophorus taipeianus)
# #202 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_13497520511v1b-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
# #203 - Generating XML for ./TW_frog_16k_wav/黑蒙西氏小雨蛙 Microhyla heymonsi_Microhyla_heymonsi.wav
#   (cName, cId, sName)=(黑蒙西氏小雨蛙,f00036,Microhyla heymonsi)
# #204 - Generating XML for ./TW_frog_16k_wav/巴氏小雨蛙 Microhyla butleri_巴氏小雨蛙吹泡泡 - YouTube (360p).wav
#   (cName, cId, sName)=(巴氏小雨蛙,f00009,Microhyla butleri)
# #205 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_13497552081h5x-l.wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #206 - Generating XML for ./TW_frog_16k_wav/台北樹蛙 Rhacophorus taipeianus_13648940971dpm-l.wav
#   (cName, cId, sName)=(台北樹蛙,f00004,Rhacophorus taipeianus)
# #207 - Generating XML for ./TW_frog_16k_wav/斑腿樹蛙 Polypedates megacephalus_13426037931ylt-l.wav
#   (cName, cId, sName)=(斑腿樹蛙,f00011,Polypedates megacephalus)
# #208 - Generating XML for ./TW_frog_16k_wav/梭德氏赤蛙 Rana sauteri_20141025.wav
#   (cName, cId, sName)=(梭德氏赤蛙,f00014,Rana sauteri)
# #209 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_13720628221ipe-l.wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #210 - Generating XML for ./TW_frog_16k_wav/小雨蛙 Microhyla ornata_A0026s001.wav
#   (cName, cId, sName)=(小雨蛙,f00008,Microhyla ornata)
# #211 - Generating XML for ./TW_frog_16k_wav/巴氏小雨蛙 Microhyla butleri_巴氏小雨蛙-完整聲音檔 - YouTube (480p).wav
#   (cName, cId, sName)=(巴氏小雨蛙,f00009,Microhyla butleri)
# #212 - Generating XML for ./TW_frog_16k_wav/史丹吉氏小雨蛙 Micryletta steinegeri_150520-012.wav
#   (cName, cId, sName)=(史丹吉氏小雨蛙,f00006,Micryletta steinegeri)
# #213 - Generating XML for ./TW_frog_16k_wav/面天樹蛙 Kurixalus idiootocus_1322109106-l.wav
#   (cName, cId, sName)=(面天樹蛙,f00034,Kurixalus idiootocus)
# #214 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_13226758632c58-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #215 - Generating XML for ./TW_frog_16k_wav/澤蛙 Fejervarya kawamurai (Rana limnocharis)_5-3-2_01.wav
#   (cName, cId, sName)=(澤蛙,f00017,Fejervarya kawamurai (Rana limnocharis))
# #216 - Generating XML for ./TW_frog_16k_wav/台北樹蛙 Rhacophorus taipeianus_13771626181qpj-l.wav
#   (cName, cId, sName)=(台北樹蛙,f00004,Rhacophorus taipeianus)
# #217 - Generating XML for ./TW_frog_16k_wav/拉都希氏赤蛙 Hylarana latouchii_134168223019i6-l.wav
#   (cName, cId, sName)=(拉都希氏赤蛙,f00010,Hylarana latouchii)
# #218 - Generating XML for ./TW_frog_16k_wav/亞洲錦蛙 Kaloula pulchra_13729212331ufi-l.wav
#   (cName, cId, sName)=(亞洲錦蛙,f00002,Kaloula pulchra)
# #219 - Generating XML for ./TW_frog_16k_wav/腹斑蛙 Babina adenopleura_腹斑蛙 - YouTube (480p).wav
#   (cName, cId, sName)=(腹斑蛙,f00023,Babina adenopleura)
# #220 - Generating XML for ./TW_frog_16k_wav/黑蒙西氏小雨蛙 Microhyla heymonsi_黑蒙西氏小雨蛙叫聲 - YouTube (480p).wav
#   (cName, cId, sName)=(黑蒙西氏小雨蛙,f00036,Microhyla heymonsi)
# #221 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_1322120967-l.wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #222 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_13388646681gly-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #223 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_1322145708-l.wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #224 - Generating XML for ./TW_frog_16k_wav/台北樹蛙 Rhacophorus taipeianus_150117-002.wav
#   (cName, cId, sName)=(台北樹蛙,f00004,Rhacophorus taipeianus)
# #225 - Generating XML for ./TW_frog_16k_wav/貢德氏赤蛙 Hylarana guentheri_植物園的蛙 一群 貢德氏赤蛙 哇哇叫 - YouTube (480p).wav
#   (cName, cId, sName)=(貢德氏赤蛙,f00031,Hylarana guentheri)
# #226 - Generating XML for ./TW_frog_16k_wav/豎琴蛙 Babina okinavana (Rana psaltes)_140413.wav
#   (cName, cId, sName)=(豎琴蛙,f00030,Babina okinavana (Rana psaltes))
# #227 - Generating XML for ./TW_frog_16k_wav/貢德氏赤蛙 Hylarana guentheri_13781794021nxz-l.wav
#   (cName, cId, sName)=(貢德氏赤蛙,f00031,Hylarana guentheri)
# #228 - Generating XML for ./TW_frog_16k_wav/中國樹蟾 Hyla chinensis_可愛的翠綠中國樹蟾，怕吵請先將音量調小 - YouTube (720p).wav
#   (cName, cId, sName)=(中國樹蟾,f00001,Hyla chinensis)
# #229 - Generating XML for ./TW_frog_16k_wav/黑眶蟾蜍 Duttaphrynus melanosticus_黑眶蟾蜍鳴叫.wmv - YouTube (360p).wav
#   (cName, cId, sName)=(黑眶蟾蜍,f00035,Duttaphrynus melanosticus)
# #230 - Generating XML for ./TW_frog_16k_wav/史丹吉氏小雨蛙 Micryletta steinegeri_Micryletta_steinegeri.wav
#   (cName, cId, sName)=(史丹吉氏小雨蛙,f00006,Micryletta steinegeri)
# #231 - Generating XML for ./TW_frog_16k_wav/福建大頭蛙 Limnonectes fujianensis_13648947311mln-l.wav
#   (cName, cId, sName)=(福建大頭蛙,f00020,Limnonectes fujianensis)
# #232 - Generating XML for ./TW_frog_16k_wav/日本樹蛙 Buergeria japonica_1322117971-l.wav
#   (cName, cId, sName)=(日本樹蛙,f00013,Buergeria japonica)
# #233 - Generating XML for ./TW_frog_16k_wav/黑蒙西氏小雨蛙 Microhyla heymonsi_1322619712-l.wav
#   (cName, cId, sName)=(黑蒙西氏小雨蛙,f00036,Microhyla heymonsi)
# #234 - Generating XML for ./TW_frog_16k_wav/中國樹蟾 Hyla chinensis_13497525721wn4-l.wav
#   (cName, cId, sName)=(中國樹蟾,f00001,Hyla chinensis)
# #235 - Generating XML for ./TW_frog_16k_wav/海蛙 Fejervarya cancrivora_13781778431qc5-l.wav
#   (cName, cId, sName)=(海蛙,f00016,Fejervarya cancrivora)
# #236 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_1322126380-l.wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #237 - Generating XML for ./TW_frog_16k_wav/梭德氏赤蛙 Rana sauteri_151009-000.wav
#   (cName, cId, sName)=(梭德氏赤蛙,f00014,Rana sauteri)
# #238 - Generating XML for ./TW_frog_16k_wav/梭德氏赤蛙 Rana sauteri_A0021s001.wav
#   (cName, cId, sName)=(梭德氏赤蛙,f00014,Rana sauteri)
# #239 - Generating XML for ./TW_frog_16k_wav/面天樹蛙 Kurixalus idiootocus_1322675695277u-l.wav
#   (cName, cId, sName)=(面天樹蛙,f00034,Kurixalus idiootocus)
# #240 - Generating XML for ./TW_frog_16k_wav/虎皮蛙 Hoplobatrachus rugulosus_20130714.wav
#   (cName, cId, sName)=(虎皮蛙,f00027,Hoplobatrachus rugulosus)
# #241 - Generating XML for ./TW_frog_16k_wav/太田樹蛙 Buergeria otai_15121056841i28-l.wav
#   (cName, cId, sName)=(太田樹蛙,f00007,Buergeria otai)
# #242 - Generating XML for ./TW_frog_16k_wav/盤古蟾蜍 Bufo bankorensis_13388762151w8h-l.wav
#   (cName, cId, sName)=(盤古蟾蜍,f00019,Bufo bankorensis)
# #243 - Generating XML for ./TW_frog_16k_wav/海蛙 Fejervarya cancrivora_13781780471nyw-l.wav
#   (cName, cId, sName)=(海蛙,f00016,Fejervarya cancrivora)
# #244 - Generating XML for ./TW_frog_16k_wav/貢德氏赤蛙 Hylarana guentheri_13862947031row-l.wav
#   (cName, cId, sName)=(貢德氏赤蛙,f00031,Hylarana guentheri)
# #245 - Generating XML for ./TW_frog_16k_wav/白頷樹蛙(布氏樹蛙) Polypedates braueri_1322139300-l.wav
#   (cName, cId, sName)=(白頷樹蛙(布氏樹蛙),f00018,Polypedates braueri)
# #246 - Generating XML for ./TW_frog_16k_wav/黑蒙西氏小雨蛙 Microhyla heymonsi_13699019691qsa-l.wav
#   (cName, cId, sName)=(黑蒙西氏小雨蛙,f00036,Microhyla heymonsi)
# #247 - Generating XML for ./TW_frog_16k_wav/諸羅樹蛙 Rhacophorus arvalis_13497543041b7a-l.wav
#   (cName, cId, sName)=(諸羅樹蛙,f00029,Rhacophorus arvalis)
